# %% [markdown]
# # Homework 1: Efficient Data Manipulation Using Numpy
#
# Welcome! This notebook will guide you from reading the question to submitting
# your answer. You do not need to finish everything at once. Work from the top of
# the notebook to the bottom, and run each code cell in order.
#
# ## Deadline
#
# Thu, Oct 8, 2026 (11:00 UTC)
#
# ## Recommended workflow
#
# 1. Read the question and the expected input/output carefully.
# 2. Run the cells in **1. Preparation**.
# 3. Complete only the `homework()` function in **2. Your Answer**.
# 4. Run the cases in **3. Test Your Answer** and compare the results.
# 5. Copy the complete `homework()` function and submit it in Omnicampus.
#
# If you change your function, run its cell again before running the later cells.

# %% [markdown]
# ## Question
#
# Implement a function that takes a 1D NumPy array of integers and returns an array containing elements that are multiples of 5 and leave a remainder of 1 when divided by 2.
#
# <br>
#
# **Inputs / Outputs:**<br>
#
#
# ```python
# homework(a: np.ndarray) -> np.ndarray
# ```
#
# | Argument | Type | Description |
# |---|---|---|
# | `a` | `np.ndarray` | 1D NumPy array of integers |
#
# | Return | Type | Description |
# |---|---|---|
# | result | `np.ndarray` | Array containing elements that are both multiples of 5 and odd |
#
# **Example:**<br>
#
# ```python
# a = np.array([1, 5, 10, 3, 4, 25, 30])
# result = homework(a)
# print(result)
# ```
# ```
# [ 5 25]
# ```
#
# **Submission Guidelines:**<br>
# 1. Import libraries
# 2. Implement `homework` that returns elements which are multiples of 5 and odd
# 3. Define a 1D NumPy array
# 4. Check output with `print`
#
# **Note:**<br>
# - Write your solution where `# Write your answer here` appears in `homework`. (Remove `# Write your answer here` before submission.)
# - Submit the full `homework` function in the Omnicampus homework submission page and click [Python code submission].
# - The return value must be a numeric array.
# - Keep everything in a single function.

# %% [markdown]
# ## 1. Preparation
#
# Run the next two cells to import NumPy and create the example input array.
# Imports belong in this preparation section, not inside `homework()`.

# %%
# 1. Import libraries
import numpy as np

# %%
# 2. Define a 1D NumPy array
a = np.array([1, 5, 10, 3, 4, 25, 30])

# %% [markdown]
# ## 2. Your Answer
#
# Complete the `homework()` function below.
#
# - Keep the function name and parameters unchanged.
# - Write your code at `# Write your answer here`.
# - Do **not** put `import` statements, file downloads, or data-loading code
#   inside the function.
# - Make sure the function returns the requested result.
#
# The temporary value `None` only keeps the starter cell runnable. Replace it
# with your own code before testing and submitting.

# %%
def homework(a):
    # Write your answer here
    my_result = None
    return my_result

# %% [markdown]
# ## 3. Test Your Answer
#
# Run each test case after completing `homework()`. Trying more than one input
# makes it easier to find mistakes and increases confidence in your answer.
#
# > **Important:** Matching all examples below does **not** guarantee a correct
# > answer or a full score. Omnicampus uses additional grading cases that are not
# > shown in this notebook.

# %% [markdown]
# ### Test Case 1: Example from the question

# %%
# Run this cell after completing homework().
your_answer = homework(a)
print("Your answer:", your_answer)

# %% [markdown]
# For this example, your answer is correct if the output is:
#
# ```text
# [ 5 25]
# ```
#
# This confirms only this example. The grader will also try other arrays,
# including arrays with negative values or no matching elements.

# %% [markdown]
# ### Test Case 2: A different array

# %%
case_2_input = np.array([11, 15, 20, 21, 35, 40, 45])
case_2_answer = homework(case_2_input)
print("Your answer:", case_2_answer)

# %% [markdown]
# The expected output is:
#
# ```text
# [15 35 45]
# ```

# %% [markdown]
# ### Test Case 3: No matching elements

# %%
case_3_input = np.array([2, 4, 6, 8])
case_3_answer = homework(case_3_input)
print("Your answer:", case_3_answer)

# %% [markdown]
# The expected output is an empty NumPy array:
#
# ```text
# []
# ```

# %% [markdown]
# ### Final checklist
#
# Before moving to Section 4, check the following:
#
# - You kept the function name and parameters unchanged.
# - Your function returns the requested result.
# - There are no `import` statements inside `homework()`.
# - There is no file download or data-loading code inside `homework()`.
# - You ran the `homework()` cell again after your latest edit.
# - You compared the output of every test case with its expected result.

# %% [markdown]
# ## 4. How to Submit Your Answer to Omnicampus

# %% [markdown]
# ### Step 1: Copy the complete `homework()` function
#
# Copy from the line beginning with `def homework(...):` through
# the final `return` line. Copy the **function itself**, not only its body.
#
# Do not copy import cells, data-download cells, the test-case cells that call
# `homework()`, the final checklist, or any printed output.

# %% [markdown]
# ### Step 2: Paste it into Omnicampus and submit
#
# Open this homework in Omnicampus, paste the complete function
# into the answer field, and click the submit button.
#
# > **🔁 You can submit as many times as you need.**
# >
# > If your result is `0.0`, revise your `homework()` function and submit it
# > again. You do not have to stop after your first submission.
#
# The submitted function must not contain library imports. The required
# libraries are provided by the grader.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Step 3: Wait for and check the grading result
#
# Grading may take a little time. If no result appears, wait a
# moment and reload the browser.
#
# - **3.0 points** means the answer is correct.
#   - If you submit after the deadline, **2.0 points** is the maximum you can get.
# - **0.0 points** means the answer is not correct yet.
# - You may revise your function and submit again.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#   ### Important Notes About Grading
#
#   1. **Your latest submission is your final result.**
#      Your grade is based on the most recent submission, not the highest score.
#      For example, if you receive `3.0` and then submit another answer that receives
#      `0.0`, your recorded result will be `0.0`.
#
#   2. **Correct submissions made during the late submission period receive a maximum of 2.0 points.**
#      Even if your answer is correct, you cannot receive `3.0` points after the
#      original deadline.
#
#   3. **The late submission window will be open to all students, including students who have already submitted.**
#      If your latest submission already shows `3.0`, you do not need to submit
#      again during the late submission period. Submitting again may replace your
#      current result.
#
#   Before you finish, make sure your latest submission shows the score you want
#   to keep.
